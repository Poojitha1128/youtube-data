# %% [markdown]
# # Exploratory Data Analysis on YouTube data

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sns

# %%
#loading dataset
data=pd.read_csv("youtube_dislike_dataset.csv")
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# # 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
# top 5 rows
data.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
#bottom 5 rows
data.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# # 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
data.info() #checking info of the dataframe
data.dtypes#checking data types of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# ...

# %%
data.shape#checking shape od the dataframe
# Out:
# (37422, 12)

# %% [markdown]
# ### inference:
# shape of the dataframe is having 37422 rows and 11 columns
# dtypes of dataset: in this dataset there are only 4 integers64 dtype variables(view_count, likes,dislikes,comment_count)
# these are numerical values and remaining are categorical values

# %% [markdown]
# # 3. Check for the Percentage of the missing values and drop or impute them.

# %%
#checking for the percentage of null values
data.isnull().mean()*100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
#comments column consists of null values and dropping down the comments column
data.drop(columns=['comments'],inplace=True)

# %%
data.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# dtype: int64

# %% [markdown]
# #### inference
# here, comments column consists of null values, missing percentage (0.42) so that we can drop this column

# %% [markdown]
# # 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
#getting statistical summary of the numerical column
data.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %% [markdown]
# ### inferences
# the statistical summary of numerical columns includes view_count,likes,dislikes,comment_count provides descriptive details about the dataset which has wide range of data distribution.
# mean of view_count is 5.69783 which is greater than median 1.3190231 so that it is positively skewed
# here the data distribution is very large due to high standard deviation

# %%
data.describe(include=["object"])
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description
# count                 37422  37422       37422
# unique                36772  28799       35630
# top     2020-10-16 04:00:10
# freq                      6   3817         589

# %% [markdown]
# ### inference
# the statistical summary of categorical column provides us good understanding of data entirely.
# top channel is sky sports football, 37422 channels, 10883 channel_title.

# %% [markdown]
# # 5. Convert datatype of column published_at from object to pandas datetime.

# %%
data["published_at"]=pd.to_datetime(data["published_at"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  datetime64[ns]
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 3.1+ MB

# %% [markdown]
# # 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
data.published_at
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37422, dtype: datetime64[ns]

# %%
data["published_month"]=(data["published_at"]).dt.month

# %%
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# # 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.

# %%
data["published_month"]=data["published_at"].dt.strftime('%B')

# %%
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# # 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
#group by months and aggregate months on to grouped months
month_published=data.groupby("published_month")["video_id"].count().sort_values(ascending=False)
month_published
# Out:
# published_month
# October      4991
# September    4880
# November     4851
# August       4262
# December     3072
# July         2340
# June         2316
# March        2258
# February     2137
# April        2126
# January      2108
# May          2081
# Name: video_id, dtype: int64

# %% [markdown]
# # 9. Find the count of unique video_id, channel_id and channel_title.

# %%
unique_video_count=data["video_id"].nunique()
unique_video_count
# Out:
# 37422

# %%
unique_channel_count=data["channel_id"].nunique()
unique_channel_count
# Out:
# 10961

# %%
unique_title_count=data["channel_title"].nunique()
unique_title_count
# Out:
# 10883

# %% [markdown]
# # 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
top_10=data.groupby(["channel_title"])["title"].count().sort_values(ascending=False).head(10)

# %%
bottom_10=data.groupby(["channel_title"])["title"].count().sort_values(ascending=True).head(10)

# %%
top_10
# Out:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: title, dtype: int64

# %%
bottom_10
# Out:
# channel_title
#    SilverName                   1
# Mini Muka                       1
# Mini Ladd                       1
# MindYourLogic                   1
# Mind Body Tonic With Dr Sita    1
# Mimi Ar                         1
# Millyz                          1
# Milkair                         1
# Milissa Grande                  1
# MikuruSong                      1
# Name: title, dtype: int64

# %% [markdown]
# # 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
max_likes=data["likes"].max()
max_likes_title=data[data["likes"]==max_likes]["title"].values[0]
max_likes_title
# Out:
# "BTS () 'Dynamite' Official MV"

# %%
#maximum number of likes for "bts() 'dynamite' official mv"

# %%
min_likes=data["likes"].min()
min_likes_title=data[data["likes"]==min_likes]["title"].values[0]
min_likes_title
# Out:
# 'Kim Kardashian\'s Must-See Moments on "Saturday Night Live" | E! News'

# %%
#minimum number of likes for 'Kim Kardashian\'s Must-See Moments on "Saturday Night Live" | E! News'.

# %% [markdown]
# # 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
max_dislikes=data["dislikes"].max()
max_dislikes_title=data[data["dislikes"]==max_dislikes]["title"].values[0]
max_dislikes_title
# Out:
# 'Cuties | Official Trailer | Netflix'

# %%
#maximum number of dislikes 'Cuties | Official Trailer | Netflix'

# %%
min_dislikes=data["dislikes"].min()
min_dislikes_title=data[data["dislikes"]==min_dislikes]["title"].values[0]
min_dislikes_title
# Out:
# 'Kim Kardashian\'s Must-See Moments on "Saturday Night Live" | E! News'

# %% [markdown]
# #### minimum number of dislikes 'Kim Kardashian\'s Must-See Moments on "Saturday Night Live" | E! News' has least number of likes and dislikes

# %% [markdown]
# # 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
data[["view_count","dislikes"]].corr()
# Out:
#             view_count  dislikes
# view_count    1.000000  0.684469
# dislikes      0.684469  1.000000

# %%
plot.scatter(data["view_count"],data["dislikes"])
plot.xlabel("view_count")
plot.ylabel("dislikes")
plot.title("relation between view_count and dislikes")
plot.show()

# %%
sns.regplot(data,x="view_count",y="dislikes")
# Out:
# <Axes: xlabel='view_count', ylabel='dislikes'>

# %% [markdown]
# ### inference
# here the correlation coefficient of view_count and dislikes is 0.68488. so there is positive correlation between both variables
# so that if increase in view_count leads to increase in dislikes

# %% [markdown]
# # 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
data[data["published_month"]=="January"]
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
data[data["published_month"]=="January"]["video_id"].count()
# Out:
# 2108

# %%
#total 2108 number of videos were published in january
